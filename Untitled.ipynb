# %%
import pandas as pd

# %%
data=pd.read_csv("Mesure_annuelle_Region_Occitanie_Polluants_Principaux (1).csv")

# %%
data
# Out:
#            X        Y       nom_dept   nom_com  insee_com  \
# 0    1.41807  43.5757  HAUTE-GARONNE  TOULOUSE      31555
# 1    1.41807  43.5757  HAUTE-GARONNE  TOULOUSE      31555
# 2    1.41807  43.5757  HAUTE-GARONNE  TOULOUSE      31555
# 3    1.41807  43.5757  HAUTE-GARONNE  TOULOUSE      31555
# 4    1.41807  43.5757  HAUTE-GARONNE  TOULOUSE      31555
# ..       ...      ...            ...       ...        ...
# 919  0.59467  43.6511           GERS      AUCH      32013
# 920  0.59467  43.6511           GERS      AUCH      32013
# 921  0.59467  43.6511           GERS      AUCH      32013
# 922  0.59467  43.6511           GERS      AUCH      32013
# 923  0.59467  43.6511           GERS      AUCH      32013
#
#                   nom_station code_station typologie influence nom_poll  \
# 0    Toulouse-Jacquier Urbain      FR50004   Urbaine      Fond       NO
# 1    Toulouse-Jacquier Urbain      FR50004   Urbaine      Fond       NO
# ...

# %%
data[data["nom_poll"]=="PM10"][["nom_com","nom_poll","date_debut","valeur"]].to_csv("villes-avec-polluant-PM10.csv",index=False)

# %%
data1=pd.read_csv("villes-avec-polluant-PM10.csv")
data1['date_debut'] = pd.to_datetime(data1['date_debut'])

# %%
data1["date_debut"].max()
data1[data1.date_debut >"2022-12-31"]
# Out:
#               nom_com nom_poll                date_debut  valeur
# 0            TOULOUSE     PM10 2023-01-01 00:00:00+00:00    14.3
# 6    PEYRUSSE-VIEILLE     PM10 2023-01-01 00:00:00+00:00    10.0
# 12           TOULOUSE     PM10 2023-01-01 00:00:00+00:00    13.4
# 18               ALBI     PM10 2023-01-01 00:00:00+00:00    13.5
# 24           TOULOUSE     PM10 2023-01-01 00:00:00+00:00     NaN
# 30           TOULOUSE     PM10 2023-01-01 00:00:00+00:00    15.7
# 36           TOULOUSE     PM10 2023-01-01 00:00:00+00:00     NaN
# 42            LOURDES     PM10 2023-01-01 00:00:00+00:00    12.4
# 48            BLAGNAC     PM10 2023-01-01 00:00:00+00:00     NaN
# 54            BLAGNAC     PM10 2023-01-01 00:00:00+00:00    14.8
# 60          BESSIERES     PM10 2023-01-01 00:00:00+00:00    12.8
# 66           TOULOUSE     PM10 2023-01-01 00:00:00+00:00    26.5
# 72             TARBES     PM10 2023-01-01 00:00:00+00:00    13.2
# ...

# %%
liste_ville=["SAINT-GIRONS","RODEZ","NIMES","TOULOUSE","AUCH","MONTPELLIER","TARBES","PERPIGNAN","ALBI","MONTAUBAN"]

# %%
data2=data1[data1['nom_com'].isin(liste_ville)]
data2=data2[data2.date_debut >"2022-12-31"]
data2.to_csv("villes_PM10.csv",index=False)
